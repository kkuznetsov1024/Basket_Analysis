# %% [markdown]
# ## Deriving New Variables
#
# #### Content
# 1. Creating subset price_range
# 2. Creating subsets for busiest days and busiest time

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
#importing the data set for orders and products
ords_prods_merge=pd.read_pickle(r'C:\Users\kirat\Documents\Career Foundy\Python\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged.pkl')

# %%
ords_prods_merge.shape
# Out:
# (32404859, 15)

# %% [markdown]
# ###### Working with the subset

# %%
#create a subset
df=ords_prods_merge[:1000000]

# %%
#define a function
def price_label(row):
    if row['prices']<=5:
        return 'Low range product'
    elif (row['prices']>5) and (row['prices']<=15):
        return 'Mid range product'
    elif row['price']>15:
        return 'High range product'
    else: return 'Not enough data'

# %%
df['price_range']=df.apply(price_label, axis=1)
# Out:
# <ipython-input-6-ec19706462f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range']=df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[df['prices']>15,'price_range_loc']='High range product'
# Out:
# C:\Users\kirat\anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\kirat\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df.loc[(df['prices']<=15) & (df['prices']>5), 'price_range_loc']='Mid range product'

# %%
df.loc[df['prices']<=5,'price_range_loc']='Low range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ###### Working with orders and products dataframe

# %% [markdown]
# ###### Adding a column 'price_range_loc'

# %%
ords_prods_merge.loc[ords_prods_merge['prices']>15,'price_range_loc']='High range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices']<=5,'price_range_loc']='Low range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices']>5) & (ords_prods_merge['prices']<=15),'price_range_loc']='Mid range product'

# %%
# dataframe now has a column to identify the range of product price
ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid range product     21860860
# Low range product     10126321
# High range product      417678
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc
# ...

# %% [markdown]
# ###### Identifying busiest day and adding a column 'busiest day'

# %%
ords_prods_merge['order_dow'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %%
result=[]
for value in ords_prods_merge['order_dow']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regular busy')

# %%
result
# Out:
# ['Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Busiest day',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# Regular busy    22416875
# Busiest day      6204182
# Least busy       3783802
# Name: busiest_day, dtype: int64

# %%
ords_prods_merge.days_since_prior_order.fillna('New Customer', inplace=True)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#   days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0           New Customer         196                  1          0   both
# 1                     15         196                  1          1   both
# 2                     21         196                  1          1   both
# 3                     29         196                  1          1   both
# 4                     28         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %% [markdown]
# ###### Identifying busiest days and adding a column 'busiest days'

# %%
result1=[]
for value in ords_prods_merge['order_dow']:
    if value == (0 or 1):
        result1.append('Busiest days')
    elif value == (4 or 3):
        result1.append('Least busy')
    else:
        result1.append('Regular busy')

# %%
ords_prods_merge['busiest_days'] = result1

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#   days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0           New Customer         196                  1          0   both
# 1                     15         196                  1          1   both
# 2                     21         196                  1          1   both
# 3                     29         196                  1          1   both
# 4                     28         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
ords_prods_merge['busiest_days'].value_counts(dropna=False)
# Out:
# Regular busy    22960827
# Busiest days     5660230
# Least busy       3783802
# Name: busiest_days, dtype: int64

# %%
ords_prods_merge['order_dow'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %% [markdown]
# ###### Identifying busiest hour and adding a column 'busiest_period_of_day'

# %%
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
result2=[]
for value in ords_prods_merge['order_hour_of_day']:
    if value == (10 or 11 or 14 or 13 or 15 or 12):
        result2.append('Most orders')
    elif value == (4 or 3 or 2 or 5 or 0 or 1):
        result2.append('Fewest orders')
    else:
        result2.append('Average orders')

# %%
result2
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
# ...

# %%
ords_prods_merge['busiest_period_of_day'] = result2

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#   days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0           New Customer         196                  1          0   both
# 1                     15         196                  1          1   both
# 2                     21         196                  1          1   both
# 3                     29         196                  1          1   both
# 4                     28         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Average orders    29589857
# Most orders        2761760
# Fewest orders        53242
# Name: busiest_period_of_day, dtype: int64

# %%
# exporting dataframe to a pickle file
ords_prods_merge.to_pickle(r'C:\Users\kirat\Documents\Career Foundy\Python\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_busy.pkl')
